# %% [markdown]
# <a href="https://colab.research.google.com/github/Samhitha559/NASSCOM/blob/main/exercise.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import os
import datetime
import random

print("--- Intermediate Python Core Exercise ---")
print("This exercise covers Python fundamentals, data structures, functions,")
print("core libraries (os, datetime, random), file handling, and exception handling.")
print("Estimated completion time: 3-4 hours.")
print("------------------------------------------")

# --- Global Data for the Exercise (Simulated Data) ---
# We'll imagine this is sensor data from various devices.
DEVICE_TYPES = ['Temperature_Sensor', 'Humidity_Sensor', 'Pressure_Sensor', 'Light_Sensor']
LOCATIONS = ['Lab1', 'Lab2', 'OfficeA', 'OfficeB', 'Warehouse']
READING_RANGES = {
    'Temperature_Sensor': (18.0, 30.0), # Celsius
    'Humidity_Sensor': (30.0, 80.0),   # Percentage
    'Pressure_Sensor': (980.0, 1030.0),# hPa
    'Light_Sensor': (100, 1000)        # Lux
}
DEVICE_TYPES = [
    'Temperature_Sensor',
    'Humidity_Sensor',
    'Pressure_Sensor',
    'Light_Sensor'
]

LOCATIONS = [
    'Lab1',
    'Lab2',
    'OfficeA',
    'OfficeB',
    'Warehouse'
]

READING_RANGES = {
    'Temperature_Sensor': (18.0, 30.0),
    'Humidity_Sensor': (30.0, 80.0),
    'Pressure_Sensor': (980.0, 1030.0),
    'Light_Sensor': (100, 1000)
}

raw_sensor_data = []

for i in range(1, 101):
    # Timestamp in the format YYYY-MM-DD HH:MM:SS
    timestamp_str = datetime.datetime.now().strftime("%Y-%m-%d %H:%M:%S")

    # Unique device ID
    device_id = f"DEV{i:03d}"

    # Randomly choose device type
    device_type = random.choice(DEVICE_TYPES)

    # Randomly choose location
    location = random.choice(LOCATIONS)

    # Generate random value based on device type
    min_value, max_value = READING_RANGES[device_type]
    value = round(random.uniform(min_value, max_value), 2)

    # Create a tuple
    reading = (timestamp_str, device_id, device_type, location, value)

    # Add tuple to the list
    raw_sensor_data.append(reading)

# Print all sensor readings
print("\nGenerated Sensor Readings:")
for reading in raw_sensor_data:
    print(reading)
# Out:
# --- Intermediate Python Core Exercise ---
# This exercise covers Python fundamentals, data structures, functions,
# core libraries (os, datetime, random), file handling, and exception handling.
# Estimated completion time: 3-4 hours.
# ------------------------------------------
#
# Generated Sensor Readings:
# ('2026-07-20 01:13:02', 'DEV001', 'Light_Sensor', 'Warehouse', 496.51)
# ('2026-07-20 01:13:02', 'DEV002', 'Light_Sensor', 'Lab2', 554.49)
# ('2026-07-20 01:13:02', 'DEV003', 'Humidity_Sensor', 'OfficeA', 35.98)
# ('2026-07-20 01:13:02', 'DEV004', 'Humidity_Sensor', 'Lab2', 44.6)
# ('2026-07-20 01:13:02', 'DEV005', 'Pressure_Sensor', 'OfficeB', 1008.85)
# ('2026-07-20 01:13:02', 'DEV006', 'Pressure_Sensor', 'OfficeB', 1020.63)
# ('2026-07-20 01:13:02', 'DEV007', 'Humidity_Sensor', 'OfficeB', 78.56)
# ('2026-07-20 01:13:02', 'DEV008', 'Pressure_Sensor', 'Lab1', 1014.84)
# ('2026-07-20 01:13:02', 'DEV009', 'Pressure_Sensor', 'OfficeA', 1021.53)
# ('2026-07-20 01:13:02', 'DEV010', 'Pressure_Sensor', 'OfficeA', 989.57)
# ('2026-07-20 01:13:02', 'DEV011', 'Light_Sensor', 'Lab1', 939.29)
# ('2026-07-20 01:13:02', 'DEV012', 'Temperature_Sensor', 'OfficeA', 20.24)
# ('2026-07-20 01:13:02', 'DEV013', 'Humidity_Sensor', 'Warehouse', 57.37)
# ('2026-07-20 01:13:02', 'DEV014', 'Humidity_Sensor', 'Lab1', 32.14)
# ('2026-07-20 01:13:02', 'DEV015', 'Pressure_Sensor', 'Warehouse', 984.23)
# ('2026-07-20 01:13:02', 'DEV016', 'Pressure_Sensor', 'OfficeB', 982.6)
# ('2026-07-20 01:13:02', 'DEV017', 'Light_Sensor', 'OfficeB', 521.13)
# ('2026-07-20 01:13:02', 'DEV018', 'Light_Sensor', 'Lab1', 798.36)
# ('2026-07-20 01:13:02', 'DEV019', 'Temperature_Sensor', 'Warehouse', 27.35)
# ('2026-07-20 01:13:02', 'DEV020', 'Humidity_Sensor', 'OfficeA', 44.38)
# ('2026-07-20 01:13:02', 'DEV021', 'Temperature_Sensor', 'Lab1', 23.75)
# ('2026-07-20 01:13:02', 'DEV087', 'Humidity_Sensor', 'Lab2', 75.18)
# ('2026-07-20 01:13:02', 'DEV088', 'Light_Sensor', 'Warehouse', 508.91)
# ('2026-07-20 01:13:02', 'DEV089', 'Pressure_Sensor', 'OfficeB', 1011.57)
# ('2026-07-20 01:13:02', 'DEV090', 'Pressure_Sensor', 'Lab1', 1007.76)
# ('2026-07-20 01:13:02', 'DEV091', 'Humidity_Sensor', 'OfficeA', 40.37)
# ('2026-07-20 01:13:02', 'DEV092', 'Temperature_Sensor', 'Lab2', 18.83)
# ('2026-07-20 01:13:02', 'DEV093', 'Temperature_Sensor', 'Warehouse', 22.9)
# ('2026-07-20 01:13:02', 'DEV094', 'Pressure_Sensor', 'OfficeA', 1021.18)
# ('2026-07-20 01:13:02', 'DEV095', 'Temperature_Sensor', 'Lab2', 23.74)
# ('2026-07-20 01:13:02', 'DEV096', 'Humidity_Sensor', 'Lab2', 79.99)
# ('2026-07-20 01:13:02', 'DEV097', 'Temperature_Sensor', 'Lab1', 26.29)
# ('2026-07-20 01:13:02', 'DEV098', 'Light_Sensor', 'OfficeA', 520.25)
# ('2026-07-20 01:13:02', 'DEV099', 'Light_Sensor', 'Lab2', 232.76)
# ('2026-07-20 01:13:02', 'DEV100', 'Pressure_Sensor', 'Lab1', 1000.07)

# %%
temperature_readings = []

for reading in raw_sensor_data:
    timestamp, device_id, device_type, location, value = reading

    if device_type == "Temperature_Sensor":
        temp_dict = {
            "timestamp": timestamp,
            "device_id": device_id,
            "location": location,
            "temperature_celsius": value
        }

        temperature_readings.append(temp_dict)

# Print the temperature readings
print("\nTemperature Readings:")
for temp in temperature_readings:
    print(temp)
# Out:
# Temperature Readings:
# {'timestamp': '2026-07-20 01:13:02', 'device_id': 'DEV012', 'location': 'OfficeA', 'temperature_celsius': 20.24}
# {'timestamp': '2026-07-20 01:13:02', 'device_id': 'DEV019', 'location': 'Warehouse', 'temperature_celsius': 27.35}
# {'timestamp': '2026-07-20 01:13:02', 'device_id': 'DEV021', 'location': 'Lab1', 'temperature_celsius': 23.75}
# {'timestamp': '2026-07-20 01:13:02', 'device_id': 'DEV023', 'location': 'Warehouse', 'temperature_celsius': 19.64}
# {'timestamp': '2026-07-20 01:13:02', 'device_id': 'DEV028', 'location': 'OfficeB', 'temperature_celsius': 18.8}
# {'timestamp': '2026-07-20 01:13:02', 'device_id': 'DEV030', 'location': 'Warehouse', 'temperature_celsius': 20.12}
# {'timestamp': '2026-07-20 01:13:02', 'device_id': 'DEV031', 'location': 'OfficeA', 'temperature_celsius': 24.18}
# {'timestamp': '2026-07-20 01:13:02', 'device_id': 'DEV034', 'location': 'Warehouse', 'temperature_celsius': 20.38}
# {'timestamp': '2026-07-20 01:13:02', 'device_id': 'DEV035', 'location': 'Warehouse', 'temperature_celsius': 28.68}
# {'timestamp': '2026-07-20 01:13:02', 'device_id': 'DEV037', 'location': 'Lab2', 'temperature_celsius': 29.7}
# {'timestamp': '2026-07-20 01:13:02', 'device_id': 'DEV038', 'location': 'Warehouse', 'temperature_celsius': 24.81}
# {'timestamp': '2026-07-20 01:13:02', 'device_id': 'DEV040', 'location': 'OfficeA', 'temperature_celsius': 23.32}
# {'timestamp': '2026-07-20 01:13:02', 'device_id': 'DEV044', 'location': 'Warehouse', 'temperature_celsius': 22.36}
# {'timestamp': '2026-07-20 01:13:02', 'device_id': 'DEV049', 'location': 'OfficeA', 'temperature_celsius': 21.71}
# {'timestamp': '2026-07-20 01:13:02', 'device_id': 'DEV058', 'location': 'Warehouse', 'temperature_celsius': 25.75}
# {'timestamp': '2026-07-20 01:13:02', 'device_id': 'DEV059', 'location': 'OfficeB', 'temperature_celsius': 29.45}
# {'timestamp': '2026-07-20 01:13:02', 'device_id': 'DEV065', 'location': 'Lab1', 'temperature_celsius': 21.93}
# {'timestamp': '2026-07-20 01:13:02', 'device_id': 'DEV074', 'location': 'Warehouse', 'temperature_celsius': 19.87}
# {'timestamp': '2026-07-20 01:13:02', 'device_id': 'DEV092', 'location': 'Lab2', 'temperature_celsius': 18.83}
# {'timestamp': '2026-07-20 01:13:02', 'device_id': 'DEV093', 'location': 'Warehouse', 'temperature_celsius': 22.9}
# {'timestamp': '2026-07-20 01:13:02', 'device_id': 'DEV095', 'location': 'Lab2', 'temperature_celsius': 23.74}
# {'timestamp': '2026-07-20 01:13:02', 'device_id': 'DEV097', 'location': 'Lab1', 'temperature_celsius': 26.29}

# %%
unique_locations = set()

for reading in raw_sensor_data:
    unique_locations.add(reading[3])   # Index 3 is the location

# Print the unique locations
print("\nUnique Locations:")
print(unique_locations)
# Out:
# Unique Locations:
# {'OfficeA', 'OfficeB', 'Lab1', 'Warehouse', 'Lab2'}

# %%
device_stats = {}

# Initialize the dictionary
for device in DEVICE_TYPES:
    device_stats[device] = (float('inf'), float('-inf'))

# Find the minimum and maximum values for each device type
for reading in raw_sensor_data:
    device_type = reading[2]
    value = reading[4]

    min_value, max_value = device_stats[device_type]

    if value < min_value:
        min_value = value

    if value > max_value:
        max_value = value

    device_stats[device_type] = (min_value, max_value)

# Display the results
print("\nDevice Statistics:")
for device, stats in device_stats.items():
    print(device, ":", stats)
# Out:
# Device Statistics:
# Temperature_Sensor : (18.8, 29.7)
# Humidity_Sensor : (32.14, 79.99)
# Pressure_Sensor : (980.81, 1025.93)
# Light_Sensor : (111.81, 939.29)

# %%
print("\n--- Task 1.5: Advanced Indexing and Slicing (Lists and Strings) ---")
sample_string = "PythonProgrammingIsFun"
# Extract elements from the 10th to the 20th (inclusive)
sliced_readings_1 = raw_sensor_data[9:20]

# Extract every 5th reading starting from the beginning
sliced_readings_2 = raw_sensor_data[::5]

# Print the results
print("\nReadings from 10th to 20th (inclusive):")
for reading in sliced_readings_1:
    print(reading)

print("\nEvery 5th reading:")
for reading in sliced_readings_2:
    print(reading)
# Out:
# --- Task 1.5: Advanced Indexing and Slicing (Lists and Strings) ---
#
# Readings from 10th to 20th (inclusive):
# ('2026-07-20 01:13:02', 'DEV010', 'Pressure_Sensor', 'OfficeA', 989.57)
# ('2026-07-20 01:13:02', 'DEV011', 'Light_Sensor', 'Lab1', 939.29)
# ('2026-07-20 01:13:02', 'DEV012', 'Temperature_Sensor', 'OfficeA', 20.24)
# ('2026-07-20 01:13:02', 'DEV013', 'Humidity_Sensor', 'Warehouse', 57.37)
# ('2026-07-20 01:13:02', 'DEV014', 'Humidity_Sensor', 'Lab1', 32.14)
# ('2026-07-20 01:13:02', 'DEV015', 'Pressure_Sensor', 'Warehouse', 984.23)
# ('2026-07-20 01:13:02', 'DEV016', 'Pressure_Sensor', 'OfficeB', 982.6)
# ('2026-07-20 01:13:02', 'DEV017', 'Light_Sensor', 'OfficeB', 521.13)
# ('2026-07-20 01:13:02', 'DEV018', 'Light_Sensor', 'Lab1', 798.36)
# ('2026-07-20 01:13:02', 'DEV019', 'Temperature_Sensor', 'Warehouse', 27.35)
# ('2026-07-20 01:13:02', 'DEV020', 'Humidity_Sensor', 'OfficeA', 44.38)
#
# Every 5th reading:
# ('2026-07-20 01:13:02', 'DEV001', 'Light_Sensor', 'Warehouse', 496.51)
# ('2026-07-20 01:13:02', 'DEV006', 'Pressure_Sensor', 'OfficeB', 1020.63)
# ('2026-07-20 01:13:02', 'DEV011', 'Light_Sensor', 'Lab1', 939.29)
# ('2026-07-20 01:13:02', 'DEV016', 'Pressure_Sensor', 'OfficeB', 982.6)
# ('2026-07-20 01:13:02', 'DEV021', 'Temperature_Sensor', 'Lab1', 23.75)
# ('2026-07-20 01:13:02', 'DEV026', 'Pressure_Sensor', 'Lab1', 1013.87)
# ('2026-07-20 01:13:02', 'DEV031', 'Temperature_Sensor', 'OfficeA', 24.18)
# ('2026-07-20 01:13:02', 'DEV036', 'Humidity_Sensor', 'OfficeB', 51.37)
# ('2026-07-20 01:13:02', 'DEV041', 'Pressure_Sensor', 'Lab1', 996.5)
# ('2026-07-20 01:13:02', 'DEV046', 'Humidity_Sensor', 'OfficeB', 32.17)
# ('2026-07-20 01:13:02', 'DEV051', 'Light_Sensor', 'Lab2', 235.64)
# ('2026-07-20 01:13:02', 'DEV056', 'Light_Sensor', 'Lab1', 152.62)
# ('2026-07-20 01:13:02', 'DEV061', 'Humidity_Sensor', 'Warehouse', 32.93)
# ('2026-07-20 01:13:02', 'DEV066', 'Pressure_Sensor', 'OfficeA', 999.14)
# ('2026-07-20 01:13:02', 'DEV071', 'Light_Sensor', 'Lab1', 308.34)
# ('2026-07-20 01:13:02', 'DEV076', 'Pressure_Sensor', 'Warehouse', 1006.18)
# ('2026-07-20 01:13:02', 'DEV081', 'Humidity_Sensor', 'OfficeA', 71.79)
# ('2026-07-20 01:13:02', 'DEV086', 'Light_Sensor', 'Lab2', 474.41)
# ('2026-07-20 01:13:02', 'DEV091', 'Humidity_Sensor', 'OfficeA', 40.37)
# ('2026-07-20 01:13:02', 'DEV096', 'Humidity_Sensor', 'Lab2', 79.99)

# %%
# Extract the substring "Programming"
substring_1 = sample_string[6:17]

# Extract the reverse of "Python" -> "nohtyP"
substring_2 = sample_string[5::-1]

# Print the results
print("\nSubstring 1:", substring_1)
print("Substring 2:", substring_2)
# Out:
# Substring 1: Programming
# Substring 2: nohtyP

# %%
# Access the device_type of the 5th reading
fifth_reading_device_type = raw_sensor_data[4][2]

# Extract the last 6 characters
device_type_suffix = fifth_reading_device_type[-6:]

# Print the results
print("\n5th Reading Device Type:", fifth_reading_device_type)
print("Device Type Suffix:", device_type_suffix)
# Out:
# 5th Reading Device Type: Pressure_Sensor
# Device Type Suffix: Sensor

# %%
# 2.1 Function to get readings by location
print("\n--- Task 2: Function Definitions and Usage ---")

def get_readings_by_location(readings_list, target_location):
    result = []

    for reading in readings_list:
        if reading[3] == target_location:
            result.append(reading)

    return result


# Example usage
location = "Lab1"
lab1_readings = get_readings_by_location(raw_sensor_data, location)

print(f"\nSensor Readings for {location}:")
for reading in lab1_readings:
    print(reading)
# Out:
# --- Task 2: Function Definitions and Usage ---
#
# Sensor Readings for Lab1:
# ('2026-07-20 01:13:02', 'DEV008', 'Pressure_Sensor', 'Lab1', 1014.84)
# ('2026-07-20 01:13:02', 'DEV011', 'Light_Sensor', 'Lab1', 939.29)
# ('2026-07-20 01:13:02', 'DEV014', 'Humidity_Sensor', 'Lab1', 32.14)
# ('2026-07-20 01:13:02', 'DEV018', 'Light_Sensor', 'Lab1', 798.36)
# ('2026-07-20 01:13:02', 'DEV021', 'Temperature_Sensor', 'Lab1', 23.75)
# ('2026-07-20 01:13:02', 'DEV024', 'Pressure_Sensor', 'Lab1', 1025.93)
# ('2026-07-20 01:13:02', 'DEV026', 'Pressure_Sensor', 'Lab1', 1013.87)
# ('2026-07-20 01:13:02', 'DEV029', 'Light_Sensor', 'Lab1', 111.81)
# ('2026-07-20 01:13:02', 'DEV032', 'Humidity_Sensor', 'Lab1', 35.33)
# ('2026-07-20 01:13:02', 'DEV039', 'Pressure_Sensor', 'Lab1', 1010.35)
# ('2026-07-20 01:13:02', 'DEV041', 'Pressure_Sensor', 'Lab1', 996.5)
# ('2026-07-20 01:13:02', 'DEV055', 'Light_Sensor', 'Lab1', 493.83)
# ('2026-07-20 01:13:02', 'DEV056', 'Light_Sensor', 'Lab1', 152.62)
# ('2026-07-20 01:13:02', 'DEV065', 'Temperature_Sensor', 'Lab1', 21.93)
# ('2026-07-20 01:13:02', 'DEV069', 'Light_Sensor', 'Lab1', 924.92)
# ('2026-07-20 01:13:02', 'DEV070', 'Pressure_Sensor', 'Lab1', 1016.25)
# ('2026-07-20 01:13:02', 'DEV071', 'Light_Sensor', 'Lab1', 308.34)
# ('2026-07-20 01:13:02', 'DEV077', 'Light_Sensor', 'Lab1', 586.96)
# ('2026-07-20 01:13:02', 'DEV078', 'Humidity_Sensor', 'Lab1', 79.07)
# ('2026-07-20 01:13:02', 'DEV082', 'Light_Sensor', 'Lab1', 928.69)
# ('2026-07-20 01:13:02', 'DEV085', 'Pressure_Sensor', 'Lab1', 1008.15)
# ('2026-07-20 01:13:02', 'DEV090', 'Pressure_Sensor', 'Lab1', 1007.76)
# ('2026-07-20 01:13:02', 'DEV097', 'Temperature_Sensor', 'Lab1', 26.29)
# ('2026-07-20 01:13:02', 'DEV100', 'Pressure_Sensor', 'Lab1', 1000.07)

# %%
# 2.2 Function to calculate average temperature

def calculate_average_temperature(temp_data_list):
    if len(temp_data_list) == 0:
        return 0.0

    total = 0

    for reading in temp_data_list:
        total += reading["temperature_celsius"]

    average = total / len(temp_data_list)
    return round(average, 2)


# Example usage
avg_temperature = calculate_average_temperature(temperature_readings)

print("\nAverage Temperature:", avg_temperature)
# Out:
# Average Temperature: 23.35

# %%
# 2.3 Function to generate a formatted report line

def generate_report_line(reading_dict):
    return f"[{reading_dict['timestamp']}] Device {reading_dict['device_id']} at {reading_dict['location']}: {reading_dict['temperature_celsius']}°C"


# Example usage
if len(temperature_readings) > 0:
    report = generate_report_line(temperature_readings[0])
    print("\nReport Line:")
    print(report)
# Out:
# Report Line:
# [2026-07-20 01:13:02] Device DEV012 at OfficeA: 20.24°C

# %%
# 3.1 Use the os module to create a new directory named 'sensor_reports'
#     in the current working directory, if it doesn't already exist.
print("\n--- Task 3: Core Library Usage ---")


reports_dir = "sensor_reports"

if not os.path.exists(reports_dir):
    os.makedirs(reports_dir)
    print(f"\nDirectory '{reports_dir}' created.")
else:
    print(f"\nDirectory '{reports_dir}' already exists.")
# Out:
# --- Task 3: Core Library Usage ---
#
# Directory 'sensor_reports' created.

# %%
# 3.2 Calculate the duration between the first and last timestamp

if len(raw_sensor_data) > 1:
    first_timestamp_str = raw_sensor_data[0][0]
    last_timestamp_str = raw_sensor_data[-1][0]

    # Convert string timestamps to datetime objects
    date_format = "%Y-%m-%d %H:%M:%S"

    first_dt = datetime.datetime.strptime(first_timestamp_str, date_format)
    last_dt = datetime.datetime.strptime(last_timestamp_str, date_format)

    # Calculate duration
    duration = last_dt - first_dt

    days = duration.days
    hours = duration.seconds // 3600
    minutes = (duration.seconds % 3600) // 60

    print(f"\nDuration of data collection: {days} days, {hours} hours, {minutes} minutes.")
else:
    print("\nNot enough data to calculate duration.")
# Out:
# Duration of data collection: 0 days, 0 hours, 0 minutes.

# %%
# 3.3 Generate a list of 5 random integers between 100 and 200 (inclusive)

random_values = []

for i in range(5):
    random_values.append(random.randint(100, 200))

print("\nRandom Values:")
print(random_values)
# Out:
# Random Values:
# [189, 107, 167, 133, 134]
